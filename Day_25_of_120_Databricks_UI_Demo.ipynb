# %%
# %sql
SHOW CATALOGS

# %%
# %sql
SELECT *
FROM circuitbox.landing.bronze_customers

# %%
# %sql
select *
from read_files('/Volumes/circuitbox/landing/operational_data/customers/customers_day1.json' , format => 'json' )
