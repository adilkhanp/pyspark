# %% [markdown]
# ### Magic commmands
# -   %python   ---- To write the python code in the cell
# -   %sql      ---- To write sql queries
# -   %md       ---- To write text
# -   %fs       ---- To access file system

# %%
# %python
spark

# %% [markdown]
# ### Reading data from a table

# %%
# %sql
select *
from circuitbox.landing.bronze_customers;

# %% [markdown]
# ### Reading data from a json file

# %%
# %sql
select *
from read_files('/Volumes/circuitbox/landing/operational_data/customers/customers_day1.json')

# %% [markdown]
# ### Reading data from a csv file

# %%
# %sql
select *
from read_files('/Volumes/circuitbox/landing/operational_data/addresses/addresses_day1.csv')

# %% [markdown]
# ### Reading data from a csv file using pyspark

# %%
# %python
df = spark.read.format('csv')\
    .option("header", "true")\
        .load('/Volumes/circuitbox/landing/operational_data/addresses/addresses_day1.csv')

# %% [markdown]
# ### Displaying data of a dataframe

# %%
# %python
display(df)

# %% [markdown]
# ### To view the table details

# %%
df.describe()

# %%
df.columns

# %% [markdown]
# ### Reading data from a file using inferschema

# %%
df = spark.read\
    .format('csv')\
     .option("header","true")\
      .option("inferSchema","true")\
      .load('/Volumes/circuitbox/landing/operational_data/addresses/addresses_day1.csv')

# %%
schema = "customer_id int, address_line_1 string, city int, state string, zip int, created_date string"

# %%
df = spark.read\
    .format('csv')\
        .schema(schema)\
     .option("header","true")\
         .option("inferSchema","false")\
      .load('/Volumes/circuitbox/landing/operational_data/addresses/addresses_day1.csv')

# %%
df.describe

# %%
df.printSchema()
